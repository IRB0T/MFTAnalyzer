# %%
import pyautogui as p
import time
from datetime import datetime 
import csv
import os
import pandas as pd

# %%
print('*'*50)
print("Script Start")
print('*'*50)
# Out:
# **************************************************
# Script Start
# **************************************************

# %%
current_working_directory = os.getcwd()
#print(current_working_directory)
for i, j, k in os.walk(current_working_directory):
    for f in k:
        if 'MFTECmd.exe' in f:
            MFTECmd_Path = str(os.path.join(i,f))
            #print(MFTECmd_Path)
        if 'extension.txt' in f:
            extension_file = str(os.path.join(i,f))
        if 'sus.txt' in f:
            suspicious_file = str(os.path.join(i,f))
        if 'Common_Path.txt' in f:
            Common_know_Path = str(os.path.join(i,f))

# %%
#Kw_List_Extension = ['.exe','.zip','.7z','.tar']
Kw_List_Extension = []
with open(extension_file,'r') as f1:
    for i in f1:
        i = i .strip()
        Kw_List_Extension.append(i)
print(Kw_List_Extension)
# Out:
# ['.exe', '.zip', '.7z', '.tar', '.rar', '.msi', '.lnk']

# %%
'''
Kw_List_suspicious = [
'netscanold.exe',
'adfind.exe',
'AADInternals',
'Impacket',
'lsass.dmp',
'svchost.exe',
'Mimikatz',
'Advanced IP Scanner.exe',
'soft.exe','any.bat','regedit_minimal.bat','HideUL.exe','rms.host.7.1.2.0.exe','lansearchpro_setup.exe',
'SMBExec.py','WMIExec.py',
]'''
Kw_List_suspicious = []
with open(suspicious_file,'r') as f1:
    for i in f1:
        i = i .strip()
        Kw_List_suspicious.append(i)
print(Kw_List_suspicious)
# Out:
# ['netscanold.exe', 'adfind.exe', 'CredentialsFileView.exe', 'Advanced IP Scanner.exe', 'soft.exe', 'svchost.exe', 'HideUL.exe', 'rms.host.7.1.2.0.exe', 'lansearchpro_setup.exe', 'Tcpview.exe', 'TreeSize.exe', 'Wireshark.exe', 'advanced_port_scanner.exe', 'eventlog rdp.exe', 'advanced_ip_scanner.exe', 'AR.exe', 'scan.exe', 'ip_scan_en_us_Release_2.5.3850.msi', 'any.bat', 'regedit_minimal.bat', 'SMBExec.py', 'WMIExec.py', 'sam', 'security', 'system', 'system.zip', 'sam.zip', 'security.zip', 'lsass.zip', 'lsass.dmp', 'svc.dmp', 'svchost.dmp', 'svchost.dmp.lnk', 'AADInternals', 'Impacket', 'Mimikatz']

# %%
Known_Path = []
with open(Common_know_Path,'r') as f1:
    for i in f1:
        i = i .strip()
        Known_Path.append(i)
print(Known_Path)
# Out:
# ['\\Advanced IP Scanner 2', '\\Advanced IP Scanner', '\\AppData\\Local\\Temp\\', '\\AppData\\Local\\Temp', '\\ProgramData\\', '\\windows\\temp\\', '\\windows\\temp', '\\users\\public\\', '\\users\\public', '\\winodws\\tasks\\', '\\Downloads\\', '\\Downloads', '\\AppData\\Local\\Temp', '\\AppData\\Roaming\\Microsoft\\windows\\start menu\\programs\\statup', '\\Windows\\Help\\', '\\Windows\\Debug\\', '\\Windows\\SysWOW64\\config\\systemprofile\\AppData\\Roaming\\Microsoft\\Windows\\', '\\windows\\svchost.exe']

# %%
start_date = str(input('Please Enter Start Date (Fromat: MM/DD/YYYY)'))
start_date = str(datetime.strptime(start_date,"%m/%d/%Y").date().strftime('%m/%d/%Y'))

end_date = str(input('Please Enter Start Date (Fromat: MM/DD/YYYY)'))
end_date = str(datetime.strptime(end_date,"%m/%d/%Y").date().strftime('%m/%d/%Y'))
# Out:
# Please Enter Start Date (Fromat: MM/DD/YYYY)02/02/2023
# Please Enter Start Date (Fromat: MM/DD/YYYY)06/02/2023

# %%
MFT_File_Path = input('Locate $MFT file: ')
print('Parsing $MFT File')
# Out:
# Locate $MFT file: C:\Users\DFIR\Desktop\MaliciousFileSearch\$MFT
# Parsing $MFT File

# %%
p.keyDown('win')
p.press("r")
p.keyUp('win')
p.typewrite('cmd')
p.press("return")
time.sleep(5)

x = p.getAllTitles()
x1 = p.getWindowsWithTitle("C:\\Windows\\system32\\cmd.exe")[0]
x1.activate()
x1.maximize()
time.sleep(5)

p.typewrite(MFTECmd_Path)
time.sleep(2)
p.typewrite(" -f ")
p.typewrite(MFT_File_Path)
time.sleep(2)
p.typewrite(" --csv ")
time.sleep(2)
p.typewrite(current_working_directory)
p.press('return')

time.sleep(140)
x1.close()

# %%
for i, j, k in os.walk(current_working_directory):
    for f in k:
        if '$MFT_Output' in f:
            MFTE_Path = str(os.path.join(i,f))
            print(MFTE_Path)
            
df = pd.read_csv(MFTE_Path,dtype='unicode')
len(df)
# Out:
# C:\Users\DFIR\Desktop\MaliciousFileSearch\20230623070018_MFTECmd_$MFT_Output.csv
# C:\Users\DFIR\Desktop\MaliciousFileSearch\20230623074019_MFTECmd_$MFT_Output.csv
# 196957

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(1)
# Out:
#   EntryNumber SequenceNumber InUse ParentEntryNumber ParentSequenceNumber  \
# 0           0              1  True                 5                    5
#
#   ParentPath FileName Extension   FileSize ReferenceCount ReparseTarget  \
# 0          .     $MFT       NaN  167772160              1           NaN
#
#   IsDirectory HasAds  IsAds  SI<FN uSecZeros Copied        SiFlags  \
# 0       False  False  False  False     False  False  Hidden|System
#
#      NameType                  Created0x10 Created0x30  \
# 0  DosWindows  2023-02-01 19:32:46.7229033         NaN
#
#               LastModified0x10 LastModified0x30         LastRecordChange0x10  \
# 0  2023-02-01 19:32:46.7229033              NaN  2023-02-01 19:32:46.7229033
#
#   LastRecordChange0x30               LastAccess0x10 LastAccess0x30  \
# 0                  NaN  2023-02-01 19:32:46.7229033            NaN
#
#   UpdateSequenceNumber LogfileSequenceNumber SecurityId ObjectIdFileDroid  \
# 0                    0             557121477        256               NaN
#
#   LoggedUtilStream ZoneIdContents
# 0              NaN            NaN

# %%
df_suspicious = pd.DataFrame(columns=['EntryNumber','SequenceNumber','ParentEntryNumber','ParentSequenceNumber','ParentPath','FileName','Extension','FileSize','Copied','Created0x10','Created0x30'])
df_count = 1

# %%
for index, row in df.iterrows():
    for j in Kw_List_suspicious:
        if row['FileName'] == j:
            df_suspicious.loc[df_count]=[row['EntryNumber'],row['SequenceNumber'],row['ParentEntryNumber'],row['ParentSequenceNumber'],row['ParentPath'],row['FileName'],row['Extension'],row['FileSize'],row['Copied'],row['Created0x10'],row['Created0x30']]
            df_count+=1

# %%
df_suspicious.head()
# Out:
#   EntryNumber SequenceNumber ParentEntryNumber ParentSequenceNumber  \
# 1        2609              1              2604                    1
# 2        3806              1              2123                    1
# 3       47642              1              3856                    1
# 4       47642              1             14536                    1
# 5       62042              1              5686                    1
#
#                                           ParentPath     FileName Extension  \
# 1                              .\Windows\diagnostics       system       NaN
# 2                                          .\Windows     security       NaN
# 3                                 .\Windows\System32  svchost.exe      .exe
# 4  .\Windows\WinSxS\amd64_microsoft-windows-servi...  svchost.exe      .exe
# 5                                 .\Windows\SysWOW64  svchost.exe      .exe
#
#   FileSize Copied                  Created0x10                  Created0x30
# 1        0  False  2022-05-07 05:24:50.6389815  2023-02-01 19:32:50.0497979
# 2        0  False  2022-05-07 05:24:50.8264863  2023-02-01 19:32:50.3257703
# 3    79920  False  2022-05-07 05:19:30.2374459  2023-02-01 19:34:30.9455767
# 4    79920  False  2022-05-07 05:19:30.2374459  2023-02-01 19:34:30.9455767
# 5    48096  False  2022-05-07 05:19:54.8838885  2023-02-01 19:35:37.9984660

# %%
df_suspicious.sort_values(by='Created0x10',inplace=True,ascending=[True])

# %%
fnm = current_working_directory+'\\'+'Suspicious.csv'
df_suspicious.to_csv(fnm,sep=',',encoding='utf-8')

# %%
#Based On Extension

# %%
df_entries_based_on_Extension = pd.DataFrame(columns=['EntryNumber','SequenceNumber','ParentEntryNumber','ParentSequenceNumber','ParentPath','FileName','Extension','FileSize','Copied','Created0x10','Created0x30'])
df_count_ = 1

# %%
df['Date'] = pd.to_datetime(df['Created0x10']).dt.strftime('%m/%d/%Y')

# %%
df['Date'] =pd.to_datetime(df['Date'])

# %%
df1 = df.loc[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

# %%
len(df1)
# Out:
# 8785

# %%
for index, row in df1.iterrows():
    for i in Kw_List_Extension:
        if row['Extension'] == i:
            df_entries_based_on_Extension.loc[df_count_]=[row['EntryNumber'],row['SequenceNumber'],row['ParentEntryNumber'],row['ParentSequenceNumber'],row['ParentPath'],row['FileName'],row['Extension'],row['FileSize'],row['Copied'],row['Created0x10'],row['Created0x30']]
            df_count_+=1

# %%
len(df_entries_based_on_Extension)
# Out:
# 151

# %%
df_entries_based_on_Extension.sort_values(by='Created0x10',inplace=True,ascending=[True])

# %%
fnm = current_working_directory+'\\'+'BasedOnExtension.csv'
df_entries_based_on_Extension.to_csv(fnm,sep=',',encoding='utf-8')

# %%
#Common Know Paths

# %%
df_entries_based_on_common_know_Path = pd.DataFrame(columns=['EntryNumber','SequenceNumber','ParentEntryNumber','ParentSequenceNumber','ParentPath','FileName','Extension','FileSize','Copied','Created0x10','Created0x30'])
df_count_ = 1

# %%
for index, row in df1.iterrows():
    for i in Known_Path:
        if i in row['ParentPath']:
            print(i)
            for j in Kw_List_Extension:
                if row['Extension'] == j:
                    df_entries_based_on_common_know_Path.loc[df_count_]=[row['EntryNumber'],row['SequenceNumber'],row['ParentEntryNumber'],row['ParentSequenceNumber'],row['ParentPath'],row['FileName'],row['Extension'],row['FileSize'],row['Copied'],row['Created0x10'],row['Created0x30']]
                    df_count_+=1
# Out:
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \Downloads
# \Downloads
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \Downloads
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \Downloads
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \AppData\Local\Temp\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp\
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \AppData\Local\Temp
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\
# \ProgramData\

# %%
df_entries_based_on_common_know_Path.sort_values(by='Created0x10',inplace=True,ascending=[True])

# %%
fnm = current_working_directory+'\\'+'BasedOnCommonKnowPath.csv'
df_entries_based_on_common_know_Path.to_csv(fnm,sep=',',encoding='utf-8')

# %%
print('*'*50)
print("Script END")
print('*'*50)
# Out:
# **************************************************
# Script END
# **************************************************
